# %% [markdown]
# <a href="https://colab.research.google.com/github/kalpana29460/Python-2026/blob/main/Python%20mini%20project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
contacts = {}

def add_contact():
    name = input("Enter Name: ")
    phone = input("Enter Phone Number: ")
    contacts[name] = phone
    print("Contact added successfully!")

def search_contact():
    name = input("Enter Name to Search: ")
    print("Phone:", contacts.get(name, "Contact not found"))

def delete_contact():
    name = input("Enter Name to Delete: ")
    if name in contacts:
        del contacts[name]
        print("Contact deleted!")
    else:
        print("Contact not found")

while True:
    print("\n1.Add  2.Search  3.Delete  4.Exit")
    choice = input("Enter choice: ")

    if choice == "1":
        add_contact()
    elif choice == "2":
        search_contact()
    elif choice == "3":
        delete_contact()
    elif choice == "4":
        break
    else:
        print("Invalid choice")
# Out:
# 1.Add  2.Search  3.Delete  4.Exit
# Enter choice: 1
# Enter Name: Kalpana
# Enter Phone Number: 7483626178
# Contact added successfully!
#
# 1.Add  2.Search  3.Delete  4.Exit
# Enter choice: 2
# Enter Name to Search: Contacts
# Phone: Contact not found
#
# 1.Add  2.Search  3.Delete  4.Exit
# Enter choice: 3
# Enter Name to Delete: Contacts
# Contact not found
#
# 1.Add  2.Search  3.Delete  4.Exit
# Enter choice: 4

# %%
tasks = []

def add_task():
    task = input("Enter Task: ")
    tasks.append(task)
    print("Task added!")

def view_tasks():
    if not tasks:
        print("No tasks found")
    else:
        for i, task in enumerate(tasks, 1):
            print(i, task)

def remove_task():
    view_tasks()
    index = int(input("Enter task number to remove: "))
    if 1 <= index <= len(tasks):
        tasks.pop(index - 1)
        print("Task removed!")
    else:
        print("Invalid task number")

while True:
    print("\n1.Add  2.View  3.Remove  4.Exit")
    choice = input("Enter choice: ")

    if choice == "1":
        add_task()
    elif choice == "2":
        view_tasks()
    elif choice == "3":
        remove_task()
    elif choice == "4":
        break
# Out:
# 1.Add  2.View  3.Remove  4.Exit
# Enter choice: 1
# Enter Task: Python first assignment
# Task added!
#
# 1.Add  2.View  3.Remove  4.Exit
# Enter choice: 2
# 1 Python first assignment
#
# 1.Add  2.View  3.Remove  4.Exit
# Enter choice: Python first assignment
#
# 1.Add  2.View  3.Remove  4.Exit
# Enter choice: 4

# %%
balance = 10000

def check_balance():
    print("Current Balance:", balance)

def deposit():
    global balance
    amount = int(input("Enter deposit amount: "))
    balance += amount
    print("Amount deposited successfully")

def withdraw():
    global balance
    amount = int(input("Enter withdrawal amount: "))
    if amount <= balance:
        balance -= amount
        print("Please collect your cash")
    else:
        print("Insufficient balance")

while True:
    print("\n1.Balance  2.Deposit  3.Withdraw  4.Exit")
    choice = input("Enter choice: ")

    if choice == "1":
        check_balance()
    elif choice == "2":
        deposit()
    elif choice == "3":
        withdraw()
    elif choice == "4":
        break
# Out:
# 1.Balance  2.Deposit  3.Withdraw  4.Exit
# Enter choice: 1
# Current Balance: 10000
#
# 1.Balance  2.Deposit  3.Withdraw  4.Exit
# Enter choice: 2
# Enter deposit amount: 1000
# Amount deposited successfully
#
# 1.Balance  2.Deposit  3.Withdraw  4.Exit
# Enter choice: 3
# Enter withdrawal amount: 500
# Please collect your cash
#
# 1.Balance  2.Deposit  3.Withdraw  4.Exit
# Enter choice: 4

# %%
questions = [
    {"q": "Capital of India?", "a": "Delhi"},
    {"q": "5 + 3 = ?", "a": "8"},
    {"q": "Python is a ___ language?", "a": "Programming"}
]

score = 0

for q in questions:
    answer = input(q["q"] + " ")
    if answer.lower() == q["a"].lower():
        score += 1

print("Your Score:", score, "/", len(questions))
# Out:
# Capital of India? Delhi
# 5 + 3 = ? 8
# Python is a ___ language? Programming
# Your Score: 2 / 3

# %%
expenses = {}

def add_expense():
    category = input("Enter Category: ")
    amount = int(input("Enter Amount: "))
    expenses[category] = expenses.get(category, 0) + amount
    print("Expense added!")

def view_expenses():
    if not expenses:
        print("No expenses recorded")
    else:
        for category, amount in expenses.items():
            print(category, ":", amount)

while True:
    print("\n1.Add Expense  2.View Expenses  3.Exit")
    choice = input("Enter choice: ")

    if choice == "1":
        add_expense()
    elif choice == "2":
        view_expenses()
    elif choice == "3":
        break
# Out:
# 1.Add Expense  2.View Expenses  3.Exit
# Enter choice: 1
# Enter Category: Grossrry
# Enter Amount: 2000
# Expense added!
#
# 1.Add Expense  2.View Expenses  3.Exit
# Enter choice: 2
# Grossrry  : 2000
#
# 1.Add Expense  2.View Expenses  3.Exit
# Enter choice: 3
