# %% [markdown]
# <a href="https://colab.research.google.com/github/kalpana29460/Python-2026/blob/main/Assignment%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = 10
print(num)
# Out:
# 10

# %%
num = int(input("enter the number: "))
print(num)
# Out:
# enter the number: 10
# 10

# %%
num= int(input("enter the first number: "))
num= int(input("enter the second number: "))
print("sum = ", num+num)
# Out:
# enter the first number: 20
# enter the second number: 10
# sum =  20

# %%
num = int(input("enter first number: "))
num = int(input("enter second number: "))
print("result =", num*num)
# Out:
# enter first number: 20
# enter second number: 30
# result = 900

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print("result =", a * b)
# Out:
# Enter first number: 10
# Enter second number: 20
# result = 200

# %%
a = int(input("enter first number: "))
b = int(input("enter second number: "))
print("modules =", a%b)
# Out:
# enter first number: 3
# enter second number: 6
# modules = 3

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("Greater number is", a)
else:
    print("Greater number is", b)
# Out:
# Enter first number: 30
# Enter second number: 80
# Greater number is 80

# %%
def add(a, b):
    return a + b

print(add(5, 3))
# Out:
# 8

# %%
3num = int(input("Enter a number: "))

if num > 0:
    print("Positive number")
elif num < 0:
    print("Negative number")
else:
    print("Zero")
# Out:
# Enter a number: 30
# Positive number
