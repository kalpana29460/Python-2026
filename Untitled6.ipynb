# %% [markdown]
# <a href="https://colab.research.google.com/github/kalpana29460/Python-2026/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to python programming ")
# Out:
# welcome to python programming

# %%
Name = "kalpana"
Age = 20
print(Name, Age)
# Out:
# kalpana 20

# %%
a = 8
b = 5
print(a+b)
print(a*b)
print(a/b)
print(a%b)
# Out:
# 13
# 40
# 1.6
# 3

# %%
name= input("enter your name :")
print ("hellow ", name)
# Out:
# enter your name :Suja
# hellow  Suja

# %%
a = int(input("enter number 1 : "))
b = int(input("enter number 2 : "))
print("sum =", a + b)
# Out:
# enter number 1 : 33
# enter number 2 : 2
# sum = 35

# %%
num = int (input("enter number : "))
if num > 0:
 print("positive number")
# Out:
# enter number : 44
# positive number

# %%
num = int(input("enter number : "))

if num % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# enter number : 2
# even

# %%
marks = int ( input(" enter your marks : "))
if marks >=90:
  print("Grade A")
elif marks >= 75:
  print("Grade B")
elif marks >= 50:
 print(" Grade C")
else:
  print("fail")
# Out:
#  enter your marks : 90
# Grade A

# %%
num = int(input("enter number: "))
if num > 0:
  if num % 2 == 0:
     print("positive and even")
  else:
     print("positive but odd")
else:
     print(" not positive")
# Out:
# enter number: 9
# positive but odd

# %%
a = int(input("enter a: "))
b = int(input("enter b: "))
c = int(input("enter c: "))
if a > b:
   if a> c:
      print(" a is largest")
   else:
      print(" c is largest ")
else:
   if b > c:
       print(" b is largest")
   else:
       print(" c is largest")
# Out:
# enter a: 10
# enter b: 32
# enter c: 62
#  c is largest

# %%
username = input("enter username: ")
password = input("enter password: ")

if username == "admin":
    if password == "1234":
        print("Login Successful")
    else:
        print("Wrong password")
else:
    print("Invalid Username")
# Out:
# enter username: Suja
# enter password: Sija@123
# Invalid Username
